# %% [markdown]
# **1. Списки - базові операції**
#
# Створіть список температур за тиждень (у градусах Цельсія) з назвою
# `temperatures` і значеннями [22, 25, 19, 23, 26, 20, 21, 22].
#
#
# Виконайте (кожен пункт оцінюється в 0.5 бала):
# - Виведіть перший елемент
# - Виведіть останній елемент
# - Додайте температуру 24
# - Видаліть температуру 19
# - Виведіть довжину списку
# - Обчисліть суму всіх температур
# - Знайдіть максимальну температуру

# %%
temperatures = [22, 25, 19, 23, 26, 20, 21, 22]

# %%
print('The first element of temperature list:', temperatures[0])
print('The last element of temperature list:', temperatures[-1])

temperatures.append(24)
print('Added 24 temperature to the list:', temperatures)

temperatures.remove(19)
print('Removed 19 temperature from the list:', temperatures)

print('The length of the list is', len(temperatures))
print('The sum of the temperatures is', sum(temperatures))
print('The max temperature is', max(temperatures))
# Out:
# The first element of temperature list: 22
# The last element of temperature list: 22
# Added 24 temperature to the list: [22, 25, 19, 23, 26, 20, 21, 22, 24]
# Removed 19 temperature from the list: [22, 25, 23, 26, 20, 21, 22, 24]
# The length of the list is 8
# The sum of the temperatures is 183
# The max temperature is 26

# %% [markdown]
# **2. Словники - базові операції**
#
# Створіть словник про себе, який містить ключі `name`, `age`, `city` і значення, які відповідають вашему імені, віку і місту (можна вставити будь-які значення, не обовʼязково свої).
#
#
# Виконайте (кожен пункт оцінюється в 0.5 бала):
# - Виведіть значення ключа "name"
# - Змініть значення ключа "age" на 21
# - Додайте новий ключ "hobby" зі значенням "programming"
# - Виведіть всі ключі
# - Виведіть всі значення

# %%
my_dict = {
    "name": "Yulia",
    "age": 22,
    "city": "Kyiv"
}

# %%
print('The name is', my_dict['name'])
# Out:
# The name is Yulia

# %%
my_dict['age'] = 21
my_dict['hobby'] = "programming"

# %%
print('The keys of my dictionary:', my_dict.keys())
print('The values of my dictionary:', my_dict.values())
print('The content of my dictionary:', my_dict.items())
# Out:
# The keys of my dictionary: dict_keys(['name', 'age', 'city', 'hobby'])
# The values of my dictionary: dict_values(['Yulia', 21, 'Kyiv', 'programming'])
# The content of my dictionary: dict_items([('name', 'Yulia'), ('age', 21), ('city', 'Kyiv'), ('hobby', 'programming')])
